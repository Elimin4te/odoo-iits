# %%
env

# %%
env['res.groups'].search_read([])
# Out:
# [{'id': 2,
#   'name': 'Access Rights',
#   'users': [2],
#   'model_access': [113,
#    112,
#    94,
#    100,
#    8,
#    11,
#    9,
#    12,
#    13,
#    14,
#    10,
#    19,
#    25,
#    39,
#    52,
#    69,
#    71,
#    105],
#   'rule_groups': [19, 12],
#   'menu_access': [4],
#   'view_access': [],
#   'comment': False,
#   'category_id': (113, 'Administration'),
#   'color': 0,
#   'full_name': 'Administration / Access Rights',
#   'share': False,
#   '__last_update': datetime.datetime(2022, 11, 10, 13, 53, 55, 870718),
#   'display_name': 'Administration / Access Rights',
#   'create_uid': (1, 'System'),
#   'create_date': datetime.datetime(2022, 11, 10, 13, 53, 55, 870718),
#   'write_uid': (1, 'System'),
#   'write_date': datetime.datetime(2022, 11, 10, 13, 53, 55, 870718),
#   'implied_ids': [1],
#   'trans_implied_ids': [1, 7]},
#  {'id': 12,
#   'name': 'Access to Private Addresses',
#   'users': [],
#   'model_access': [],
#   'rule_groups': [11],
# ...
